# %% [markdown]
# #### Importamos las librerías

# %%
import numpy as np
import pandas as pd

from bokeh.io import output_notebook, show
from bokeh.plotting import figure
from bokeh.core.properties import value
from bokeh.palettes import Spectral6, Greys, RdGy, Blues, Greys256
from bokeh.models import ColumnDataSource, Title, Label, LabelSet, Slope, Span, BoxAnnotation
from bokeh.transform import dodge, linear_cmap


output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# #### Primer ejercicio
# <img src="images/figura_1.png">

# %%
# Creamos dataframe para graficar
interest = ['Bored', 'Not great', 'OK', 'Kind of interested', 'Excited', 'Some interest']
before = [11, 5, 40, 25, 19, 44]
after = [12, 6, 14, 30, 38, 68]
data = {'interest': interest, 'before': before, 'after': after}

df = pd.DataFrame(data)
df = df.loc[df['interest'] != 'Some interest']
df
# Out:
#              interest  before  after
# 0               Bored      11     12
# 1           Not great       5      6
# 2                  OK      40     14
# 3  Kind of interested      25     30
# 4             Excited      19     38

# %%
interest = list(df['interest'])
categoty = ['before', 'after']
y = list(df['before'])

mapper = linear_cmap(field_name='before', palette=Greys256[170:120:-20],low=min(y) ,high=max(y))

source = ColumnDataSource(df)

p = figure(x_range=interest, y_range=(0, 70), plot_height=350, plot_width=350, title="How do you feel about science?",
           toolbar_location=None, tools="")

p.vbar(x=dodge('interest', -0.23, range=p.x_range), color=mapper, top='before', width=0.45, source=source)

p.vbar(x=dodge('interest',  0.23,  range=p.x_range), top='after', width=0.45, source=source,
       color="#718dbf")


p.add_layout(Title(text="Bottom Centered Title", align="left"), "below")
p.add_layout(Title(text="Bottom Centered Title", align="left"), "below")

p.yaxis.visible=False
p.xaxis.axis_line_color = None
p.xaxis.major_tick_line_color = None
p.x_range.range_padding = 0
p.ygrid.grid_line_color=None
p.xgrid.grid_line_color = None
p.legend.location = "top_left"
p.legend.orientation = "vertical"

show(p)
# Out:
#   <div class="bk-root" id="49ada6d7-7bc8-48a2-911e-1d33d153877e" data-root-id="1183"></div>

# %%
Greys256[152:-100]
# Out:
# ['#989898', '#999999', '#9a9a9a', '#9b9b9b']
